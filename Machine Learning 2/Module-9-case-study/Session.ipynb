# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# read daṇta
churn = pd.read_csv("telecom_churn_data.csv")

# %%
churn['target'] = (churn[['total_ic_mou_9','total_og_mou_9','vol_2g_mb_9','vol_3g_mb_9']].sum(axis=1)==0).astype(int)

# %%
churn['target']
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99994    0
# 99995    0
# 99996    1
# 99997    0
# 99998    1
# Name: target, Length: 99999, dtype: int32

# %%
(churn['target'].value_counts(1)*100).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
(churn['target'].value_counts(1)*100).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='target'>

# %%
churn.circle_id.value_counts()
# Out:
# temp    99999
# Name: circle_id, dtype: int64

# %%
churn.circle_id.apply(lambda x:x[0])
# Out:
# 0        t
# 1        t
# 2        t
# 3        t
# 4        t
#         ..
# 99994    t
# 99995    t
# 99996    t
# 99997    t
# 99998    t
# Name: circle_id, Length: 99999, dtype: object

# %%
churn.circle_id = churn.circle_id.map({109:'temp'})

# %%
((churn['total_ic_mou_9']==0.0)&(churn['total_og_mou_9']==0.0)).astype(int)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99994    0
# 99995    0
# 99996    1
# 99997    0
# 99998    1
# Length: 99999, dtype: int32

# %%
churn['target'] = (churn['total_ic_mou_9']==0.0).astype(int)

# %%
churn.shape
# Out:
# (99999, 227)

# %%
churn['target'].value_counts(1)*100
# Out:
# 0    88.514885
# 1    11.485115
# Name: target, dtype: float64

# %%
(churn['target'].value_counts(1)*100).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='target'>

# %%
(churn.isna().sum()/churn.shape[0])*100
# Out:
# mobile_number     0.00000
# circle_id         0.00000
# loc_og_t2o_mou    1.01801
# std_og_t2o_mou    1.01801
# loc_ic_t2o_mou    1.01801
#                    ...
# aug_vbc_3g        0.00000
# jul_vbc_3g        0.00000
# jun_vbc_3g        0.00000
# sep_vbc_3g        0.00000
# target            0.00000
# Length: 227, dtype: float64

# %%
(churn.isna().sum()/churn.shape[0])*100
# Out:
# mobile_number     0.00000
# circle_id         0.00000
# loc_og_t2o_mou    1.01801
# std_og_t2o_mou    1.01801
# loc_ic_t2o_mou    1.01801
#                    ...
# aug_vbc_3g        0.00000
# jul_vbc_3g        0.00000
# jun_vbc_3g        0.00000
# sep_vbc_3g        0.00000
# target            0.00000
# Length: 227, dtype: float64

# %%
# !pip install missingno
import missingno as msno 


# Visualize missing values as a matrix 
msno.matrix(churn[])
# Out:
# <AxesSubplot:>

# %%
churn.total_rech_data_6 * churn.av_rech_amt_data_6
# Out:
# 0         252.0
# 1           NaN
# 2           NaN
# 3           NaN
# 4          56.0
#           ...
# 99994       NaN
# 99995       NaN
# 99996      78.0
# 99997    1749.0
# 99998     154.0
# Length: 99999, dtype: float64

# %%
# look at initial rows of the data
churn.head(10)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
# 5     7000286308        109             0.0             0.0             0.0
# 6     7001051193        109             0.0             0.0             0.0
# 7     7000701601        109             0.0             0.0             0.0
# 8     7001524846        109             0.0             0.0             0.0
# 9     7001864400        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# ...

# %%
# feature type summary
churn.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 226 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   mobile_number             int64
#  1   circle_id                 int64
#  2   loc_og_t2o_mou            float64
#  3   std_og_t2o_mou            float64
#  4   loc_ic_t2o_mou            float64
#  5   last_date_of_month_6      object
#  6   last_date_of_month_7      object
#  7   last_date_of_month_8      object
#  8   last_date_of_month_9      object
#  9   arpu_6                    float64
#  10  arpu_7                    float64
#  11  arpu_8                    float64
#  12  arpu_9                    float64
#  13  onnet_mou_6               float64
#  14  onnet_mou_7               float64
#  15  onnet_mou_8               float64
#  16  onnet_mou_9               float64
#  17  offnet_mou_6              float64
#  18  offnet_mou_7              float64
# ...

# %%
# look at data statistics
churn.describe(include='all')
# Out:
#         mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count    9.999900e+04    99999.0         98981.0         98981.0
# unique            NaN        NaN             NaN             NaN
# top               NaN        NaN             NaN             NaN
# freq              NaN        NaN             NaN             NaN
# mean     7.001207e+09      109.0             0.0             0.0
# std      6.956694e+05        0.0             0.0             0.0
# min      7.000000e+09      109.0             0.0             0.0
# 25%      7.000606e+09      109.0             0.0             0.0
# 50%      7.001205e+09      109.0             0.0             0.0
# 75%      7.001812e+09      109.0             0.0             0.0
# max      7.002411e+09      109.0             0.0             0.0
#
#         loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7  \
# count          98981.0                99999                99398
# ...
